# %% [markdown]
# You are given the MNIST dataset consisting of 28×28 grayscale images of handwritten digits (0–9). Design and implement a Convolutional Neural Network to classify these digits.
#
# The dataset is available through TensorFlow’s datasets library. You may use the following reference to get started: https://blog.tensorflow.org/2019/02/introducing-tensorflow-datasets.html
#
# Notes:
# You are not allowed to use AI-generated code for this task.
# You must build the model using a Sequential architecture, though you may use helper functions provided by the library.
# Please inform us if you are not familiar with the TensorFlow library and mention which library you are comfortable using instead.
#
# Kindly upload your code to GitHub

# %%
import tensorflow as tf
import numpy as np
import tensorflow_datasets as tfds

datasets = tf.keras.datasets
layers = tf.keras.layers
models = tf.keras.models

# %%
#load the MNIST dataset

mnist = datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
# Initializing the neural network
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# %%
#show summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 3, 3, 64)       │        36,928 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 55,744 (217.75 KB)
#  Trainable params: 55,744 (217.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))

# %%
#show summary
model.summary()

# %%
# Compiling the model

model.compile(optimizer='adam', loss='mse')

# %%
# Fitting the model
history = model.fit(
    x_train,
    y_train,
    epochs=10
)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Fitting the model
# ----> 2 model.fit(
#       3     x_train,
#       4     y_train,
#       5     epochs=10
#       6 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/keras/src/losses/losses.py:1787, in mean_squared_error(y_true, y_pred)
#    1785 y_true = ops.convert_to_tensor(y_true, dtype=y_pred.dtype)
#    1786 y_true, y_pred = squeeze_or_expand_to_same_rank(y_true, y_pred)
# -> 1787 return ops.mean(ops.square(y_true - y_pred), axis=-1)
#
# ValueError: Dimensions must be equal, but are 32 and 64 for '{{node compile_loss/mse/sub}} = Sub[T=DT_FLOAT](compile_loss/mse/Cast, sequential_1/conv2d_2_1/Relu)' with input shapes: [32], [32,3,3,64].

# %%
y_pred = model.predict(y_test)

# %%
#accuracy_score(y_test, y_pred)

# %%
model.save('mnist_model')
